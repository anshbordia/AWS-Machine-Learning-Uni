# %% [markdown]
# ![MLU Logo](../data/MLU_Logo.png)

# %% [markdown]
# # <a name="0">Machine Learning Accelerator - Natural Language Processing - Lecture 1</a>
#
# ## Final Project: K Nearest Neighbors Model for the IMDB Movie Review Dataset
#
# For the final project, build a K Nearest Neighbors model to predict the sentiment (positive or negative) of movie reviews. The dataset is originally hosted here: http://ai.stanford.edu/~amaas/data/sentiment/
#
# Use the notebooks from the class and implement the model, train and test with the corresponding datasets.
#
# You can follow these steps:
# 1. Read training-test data (Given)
# 2. Train a KNN classifier (Implement)
# 3. Make predictions on your test dataset (Implement)
#
# __You can use the KNN Classifier from here: https://scikit-learn.org/stable/modules/generated/sklearn.neighbors.KNeighborsClassifier.html__

# %% [markdown]
# ## 1. Reading the dataset
#
# We will use the __pandas__ library to read our dataset.

# %% [markdown]
# #### __Training data:__
# Let's read our training data. Here, we have the text and label fields. Labe is 1 for positive reviews and 0 for negative reviews.

# %%
import pandas as pd

train_df = pd.read_csv('../data/final_project/imdb_train.csv', header=0)
train_df.head()
# Out:
#                                                 text  label
# 0  This movie makes me want to throw up every tim...      0
# 1  Listening to the director's commentary confirm...      0
# 2  One of the best Tarzan films is also one of it...      1
# 3  Valentine is now one of my favorite slasher fi...      1
# 4  No mention if Ann Rivers Siddons adapted the m...      0

# %% [markdown]
# #### __Test data:__

# %%
import pandas as pd

test_df = pd.read_csv('../data/final_project/imdb_test.csv', header=0)
test_df.head()
# Out:
#                                                 text  label
# 0  What I hoped for (or even expected) was the we...      0
# 1  Garden State must rate amongst the most contri...      0
# 2  There is a lot wrong with this film. I will no...      1
# 3  To qualify my use of "realistic" in the summar...      1
# 4  Dirty War is absolutely one of the best politi...      1

# %% [markdown]
# # Data Exploration

# %%
#Exlore distribution of classes
print(train_df['label'].value_counts())
print(test_df['label'].value_counts())

#Explore NaNs
print(train_df.isnull().values.any())
print(test_df.isnull().values.any())
# Out:
# 0    12500
# 1    12500
# Name: label, dtype: int64
# 0    12500
# 1    12500
# Name: label, dtype: int64
# False
# False

# %% [markdown]
# # Preprocessing

# %%
#Download relevant nltk packages
import nltk, re
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/anshbordia/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/anshbordia/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/anshbordia/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
#Stop words removal
#Not all stop words are bad in this scenario. We will retain some helpful words as shown below
from nltk.corpus import stopwords
excluding = ['against', 'not', 'don', "don't",'ain', 'aren', "aren't", 'couldn', "couldn't",
             'didn', "didn't", 'doesn', "doesn't", 'hadn', "hadn't", 'hasn', "hasn't", 
             'haven', "haven't", 'isn', "isn't", 'mightn', "mightn't", 'mustn', "mustn't",
             'needn', "needn't",'shouldn', "shouldn't", 'wasn', "wasn't", 'weren', 
             "weren't", 'won', "won't", 'wouldn', "wouldn't"]

accepted_stopwords = list(set(stopwords.words('english')).symmetric_difference(set(excluding)))

# %%
#Setup tokenizer and lemmatizer for preprocessing
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer 

lemmatizer = WordNetLemmatizer()

# %%
"""
Convert to lower case
Remove trailing white space
Remove intermediate extra white space
Remove HTML tags
Lemmatize individual words
"""
def preprocess(text):
    processed_sentences = []
    temp = ""
    for i in range(0, len(text)):
        temp = text[i]
        temp = temp.lower()
        temp = temp.strip()
        temp = re.sub('\s+', ' ', temp)
        temp = re.compile('<.*?>').sub('', temp)
        
        selected_words = []
        for word in word_tokenize(temp):
            if(word not in accepted_stopwords):
                selected_words.append(lemmatizer.lemmatize(word))
        
        processed_sentences.append(" ".join(selected_words))
        temp = ""
    return processed_sentences

# %%
train_X = preprocess(train_df['text'].values)
test_X = preprocess(test_df['text'].values)

# %%
train_y = train_df['label'].values
test_y = test_df['label'].values

# %% [markdown]
# # Building Features

# %%
# Build TF-IDF features to be fed into model
from sklearn.feature_extraction.text import TfidfVectorizer
vectorizer = TfidfVectorizer(max_features = 5000)
train_X = vectorizer.fit_transform(train_X)

# %%
print(vectorizer.get_feature_names())
# Out:
# ['00', '000', '10', '100', '11', '12', '13', '13th', '14', '15', '16', '17', '18', '1930', '1930s', '1933', '1936', '1939', '1940', '1950', '1950s', '1960', '1960s', '1968', '1970', '1970s', '1971', '1972', '1973', '1978', '1980', '1980s', '1983', '1984', '1987', '1988', '1989', '1990', '1993', '1995', '1996', '1997', '1999', '19th', '1st', '20', '2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008', '20th', '22', '24', '25', '2nd', '30', '3000', '35', '3d', '3rd', '40', '45', '50', '60', '70', '70s', '75', '80', '80s', '90', '99', 'abandoned', 'abc', 'ability', 'able', 'about', 'abraham', 'absence', 'absent', 'absolute', 'absolutely', 'absurd', 'absurdity', 'abuse', 'abused', 'abusive', 'abysmal', 'academy', 'accent', 'accept', 'acceptable', 'accepted', 'access', 'accident', 'accidentally', 'acclaimed', 'accompanied', 'accomplish', 'accomplished', 'according', 'account', 'accuracy', 'accurate', 'accused', 'achieve', 'achieved', 'achievement', 'acid', 'across', 'act', 'acted', 'acting', 'action', 'active', 'activity', 'actor', 'actors', 'actress', 'actual', 'actually', 'ad', 'adam', 'adaptation', 'adapted', 'add', 'added', 'addict', 'addicted', 'adding', 'addition', 'address', 'adequate', 'admire', 'admit', 'admittedly', 'adolescent', 'adopted', 'adorable', 'adult', 'advance', 'advanced', 'advantage', 'adventure', 'advertising', 'advice', 'advise', 'affair', 'affect', 'affected', 'affection', 'afford', 'aforementioned', 'afraid', 'africa', 'african', 'after', 'afternoon', 'afterwards', 'again', 'against', 'age', 'aged', 'agency', 'agenda', 'agent', 'aging', 'ago', 'agree', 'agreed', 'agrees', 'ah', 'ahead', 'ai', 'aid', 'aim', 'aimed', 'air', 'aired', 'airplane', 'airport', 'aka', 'akshay', 'al', 'ala', 'alan', 'albeit', 'albert', 'album', 'alcohol', 'alcoholic', 'alec', 'alert', 'alex', 'alexander', 'alfred', 'alice', 'alicia', 'alien', 'alike', 'alison', 'alive', 'all', 'allen', 'alley', 'allow', 'allowed', 'allowing', 'allows', 'ally', 'almost', 'alone', 'along', 'alongside', 'already', 'alright', 'also', 'alternate', 'alternative', 'although', 'altman', 'altogether', 'always', 'amanda', 'amateur', 'amateurish', 'amazed', 'amazing', 'amazingly', 'amazon', 'ambiguous', 'ambition', 'ambitious', 'america', 'american', 'amitabh', 'among', 'amongst', 'amount', 'amused', 'amusement', 'amusing', 'amy', 'an', 'analysis', 'ancient', 'and', 'anderson', 'andre', 'andrew', 'andy', 'angel', 'angela', 'angeles', 'anger', 'angle', 'angry', 'animal', 'animated', 'animation', 'animator', 'anime', 'ann', 'anna', 'anne', 'annie', 'annoyed', 'annoying', 'another', 'answer', 'ant', 'anthony', 'anti', 'antic', 'antonioni', 'antwone', 'anybody', 'anymore', 'anyone', 'anything', 'anyway', 'anyways', 'anywhere', 'apart', 'apartment', 'ape', 'appalling', 'apparent', 'apparently', 'appeal', 'appealing', 'appear', 'appearance', 'appeared', 'appearing', 'appears', 'appreciate', 'appreciated', 'appreciation', 'approach', 'appropriate', 'appropriately', 'april', 'arab', 'arc', 'area', 'arguably', 'argue', 'argument', 'arm', 'armed', 'army', 'arnold', 'around', 'arrested', 'arrival', 'arrive', 'arrived', 'arrives', 'arrogant', 'arrow', 'art', 'arthur', 'artificial', 'artist', 'artistic', 'as', 'ashamed', 'ashley', 'asian', 'aside', 'ask', 'asked', 'asking', 'asks', 'asleep', 'aspect', 'aspiring', 'ass', 'assassin', 'assault', 'assigned', 'assistant', 'associate', 'associated', 'assume', 'assumed', 'astaire', 'astonishing', 'asylum', 'at', 'atlantis', 'atmosphere', 'atmospheric', 'atrocious', 'attached', 'attack', 'attacked', 'attempt', 'attempted', 'attempting', 'attenborough', 'attend', 'attention', 'attitude', 'attorney', 'attracted', 'attraction', 'attractive', 'audience', 'audio', 'audition', 'aunt', 'austen', 'austin', 'australia', 'australian', 'authentic', 'author', 'authority', 'automatically', 'available', 'average', 'avoid', 'avoided', 'awake', 'award', 'aware', 'away', 'awe', 'awesome', 'awful', 'awfully', 'awhile', 'awkward',  ...

# %%
vectorizer.vocabulary_
# Out:
# {'movie': 2928,
#  'make': 2719,
#  'want': 4817,
#  'throw': 4503,
#  'every': 1568,
#  'time': 4518,
#  'see': 3893,
#  'take': 4394,
#  'first': 1758,
#  'plot': 3324,
#  'leave': 2567,
#  'sea': 3878,
#  'daughter': 1162,
#  'go': 1950,
#  'character': 779,
#  'give': 1938,
#  'new': 3008,
#  'animal': 261,
#  'name': 2965,
#  'crappy': 1070,
#  'animation': 263,
#  'biggest': 503,
#  'suck': 4307,
#  'factor': 1650,
#  'possible': 3369,
#  'get': 1927,
#  'little': 2631,
#  'basically': 433,
#  'copy': 1035,
#  'll': 2636,
#  'horror': 2184,
#  'step': 4223,
#  'people': 3241,
#  '1st': 44,
#  'prince': 3425,
#  'eric': 1543,
#  'still': 4233,
#  'line': 2617,
#  'whole': 4886,
#  'annoying': 271,
#  'not': 3049,
#  'spirit': 4161,
#  'saw': 3844,
#  'fact': 1649,
#  'exact': 1578,
#  'opposite': 3128,
#  'le': 2554,
#  'cute': 1129,
#  'convincing': 1027,
#  'joke': 2425,
#  'funny': 1878,
#  'anymore': 281,
#  'kid': 2475,
#  'talk': 4400,
#  'dumb': 1412,
#  'voice': 4788,
#  'king': 2485,
#  'probably': 3436,
#  'best': 490,
#  'love': 2674,
#  'melody': 2806,
#  'appear': 295,
#  'like': 2607,
#  'said': 3818,
#  'use': 4717,
#  'evil': 1576,
#  'villain': 4769,
#  'sister': 4044,
#  'feel': 1709,
#  'always': 226,
#  'lived': 2633,
#  'shadow': 3954,
#  'would': 4960,
#  'scared': 3850,
#  'showed': 3997,
#  'knife': 2492,
#  'ca': 667,
#  'anything': 283,
#  'right': 3733,
#  'failure': 1657,
#  'replaced': 3666,
#  'stupid': 4287,
#  'sidekick': 4007,
#  'tip': 4525,
#  'try': 4622,
#  'hero': 2114,
#  'fail': 1653,
#  'trying': 4623,
#  'predictable': 3388,
#  'become': 456,
#  'end': 1500,
#  'yawn': 4980,
#  'shark': 3965,
#  'turned': 4629,
#  'smaller': 4081,
#  'he': 2082,
#  'really': 3580,
#  'bad': 406,
#  'think': 4480,
#  'chemistry': 807,
#  'good': 1961,
#  'ah': 175,
#  'lovely': 2676,
#  'un': 4649,
#  'sing': 4034,
#  'higher': 2124,
#  'punch': 3489,
#  'face': 1645,
#  'fake': 1663,
#  'sweet': 4376,
#  'clumsy': 896,
#  'fun': 1873,
#  'find': 1748,
#  'boring': 566,
#  'unoriginal': 4698,
#  'simplistic': 4026,
#  'watch': 4836,
#  'certain': 757,
#  'part': 3207,
#  'call': 676,
#  'disney': 1327,
#  'demand': 1214,
#  'horrible': 2179,
#  'made': 2702,
#  'sequel': 3926,
#  'wonderful': 4935,
#  'original': 3136,
#  'comparing': 943,
#  'ed': 1443,
#  'wood': 4940,
#  'ever': 1567,
#  'even': 1563,
#  'bored': 564,
#  'listening': 2626,
#  'director': 1299,
#  'commentary': 931,
#  'whilst': 4882,
#  'watching': 4839,
#  'film': 1739,
#  'guy': 2030,
#  'play': 3313,
#  'making': 2723,
#  'kind': 2483,
#  'thing': 4479,
#  'teenager': 4433,
#  're': 3560,
#  'going': 1955,
#  'could': 1048,
#  'write': 4969,
#  'book': 559,
#  'screenplay': 3872,
#  'award': 390,
#  'winning': 4912,
#  'sitcom': 4046,
#  'interesting': 2336,
#  'idea': 2221,
#  'buried': 647,
#  'some': 4110,
#  'one': 3117,
#  'else': 1478,
#  'totally': 4557,
#  'badly': 408,
#  'executed': 1595,
#  'laughably': 2541,
#  'thought': 4489,
#  'out': 3147,
#  'script': 3875,
#  'the': 4465,
#  'dire': 1293,
#  'performance': 3247,
#  'engaging': 1510,
#  'though': 4488,
#  'blame': 524,
#  'actor': 120,
#  'required': 3676,
#  'rather': 3553,
#  'hand': 2046,
#  'pointed': 3331,
#  'camera': 682,
#  'told': 4536,
#  'know': 2496,
#  'better': 494,
#  'say': 3845,
#  'musician': 2952,
#  'jon': 2426,
#  'excellent': 1583,
#  'row': 3786,
#  'boat': 548,
#  'acceptable': 95,
#  'leading': 2557,
#  'man': 2727,
#  'as': 330,
#  'stand': 4195,
#  'cast': 731,
#  'whatsoever': 4875,
#  'beautiful': 452,
#  'opportunity': 3126,
#  'classic': 862,
#  'sex': 3947,
#  'parallel': 3199,
#  'passed': 3217,
#  'order': 3132,
#  'vampire': 4736,
#  'blood': 538,
#  'co': 897,
#  'hunter': 2211,
#  'given': 1939,
#  'mind': 2854,
#  'looked': 2655,
#  'vaguely': 4731,
#  'interested': 2335,
#  'throughout': 4502,
#  'rest': 3694,
#  'real': 3570,
#  'moment': 2893,
#  'sexual': 3948,
#  'tension': 4446,
#  'two': 4640,
#  'female': 1715,
#  'lead': 2555,
#  'originally': 3138,
#  'intended': 2327,
#  'silent': 4015,
#  'sequence': 3927,
#  'excuse': 1594,
#  'pointless': 3332,
#  'exposition': 1630,
#  'suppose': 4347,
#  'finished': 1754,
#  'product': 3445,
#  'worse': 4954,
#  'lot': 2667,
#  'frankly': 1846,
#  'silly': 4017,
#  'forgettable': 1814,
#  'trashy': 4591,
#  'sexy': 3951,
#  'enough': 1520,
#  'gory': 1967,
#  'entertaining': 1528,
#  'bloody': 539,
#  'romp': 3771,
#  'left': 2571,
#  'comedy': 923,
#  'wrong': 4974,
#  'reason': 3582,
#  'tarzan': 4410,
#  'also': 220,
#  'action': 117,
#  'packed': 3174,
#  'graphic': 1982,
#  'picking': 3285,
#  'year': 4982,
#  'ape': 289,
#  'hamilton': 2042,
#  'asked': 336,
#  'rich': 3720,
#  'friend': 1858,
#  'back': 402,
#  'elephant': 1473,
#  'arrives': 322,
#  'carrying': 724,
#  'dress': 1384,
#  'hope': 2171,
#  'win': 4907,
#  'jane': 2390,
#  'map': 2740,
#  'stolen': 4240,
#  'becomes': 457,
#  'mad': 2701,
#  'capture': 701,
#  'expedition': 1609,
#  'finally': 1746,
#  'thief': 4477,
#  'party': 3212,
#  'dead': 1171,
#  'surrounded': 4359,
#  'choice': 821,
#  'fight': 1730,
#  'way': 4843,
#  'soon': 4120,
#  'pan': 3192,
#  'fire': 1755,
#  'eventually': 1566,
#  'show': 3994,
#  'everyone': 1571,
#  'infamous': 2293,
#  'heavily': 2095,
#  'violence': 4771,
#  'today': 4532,
#  'standard': 4196,
#  'pg': 3265,
#  '13': 6,
#  'remove': 3654,
#  'hint': 2132,
#  'nudity': 3068,
#  'several': 3945,
#  'minute': 2864,
#  'long': 2652,
#  'nude': 3067,
#  'swim': 4377,
#  'scene': 3853,
#  'involving': 2361,
#  'full': 1870,
#  'recently': 3591,
#  'restored': 3696,
#  'clear': 866,
#  'version': 4750,
#  'reduced': 3604,
#  '20': 45,
#  'run': 3797,
#  'tv': 4632,
#  'adult': 143,
#  'romantic': 3769,
#  'touching': 4560,
#  'filled': 1736,
#  'everything': 1572,
#  'amazing': 231,
#  'almost': 214,
#  'sort': 4124,
#  'well': 4862,
#  'alone': 215,
#  'adventure': 147,
#  'need': 2990,
#  'seen': 3902,
#  'enjoy': 1513,
#  'theme': 4470,
#  'set': 3940,
#  'great': 1988,
#  'deal': 1174,
#  'if': 2227,
#  'flaw': 1773,
#  'perhaps': 3252,
#  'aged': 166,
#  'screen': 3870,
#  'often': 3104,
#  'obvious': 3082,
#  'suit': 4323,
#  'many': 2739,
#  'effect': 1458,
#  'however': 2196,
#  'level': 2593,
#  'top': 4550,
#  'notch': 3052,
#  'you': 4992,
#  'big': 501,
#  'popcorn': 3349,
#  'let': 2590,
#  'valentine': 4732,
#  'favorite': 1697,
#  'slasher': 4063,
#  'death': 1180,
#  'elaborate': 1468,
#  'acting': 116,
#  'much': 2936,
#  'jennifer': 2401,
#  'david': 1164,
#  'main': 2713,
#  'pretty': 3411,
#  'small': 4080,
#  'role': 3762,
#  'played': 3314,
#  'exception': 1585,
#  'list': 2623,
#  'richards': 3722,
#  'glad': 1941,
#  'spoiler': 4172,
#  'definitely': 1202,
#  'scream': 3868,
#  'mention': 2816,
#  'ann': 266,
#  'river': 3744,
#  'adapted': 128,
#  'material': 2774,
#  'house': 2191,
#  'next': 3014,
#  'door': 1358,
#  '1970s': 25,
#  'novel': 3061,
#  'title': 4529,
#  'someone': 4113,
#  'lifetime': 2602,
#  'directed': 1295,
#  'canadian': 690,
#  'jeff': 2399,
#  'read': 3566,
#  'ago': 171,
#  'decided': 1188,
#  'chance': 771,
#  'cable': 669,
#  'clearly': 867,
#  'television': 4435,
#  'critical': 1099,
#  'commercial': 933,
#  'course': 1057,
#  'watched': 4838,
#  'star': 4200,
#  'flynn': 1787,
#  'boyle': 583,
#  'sport': 4177,
#  'look': 2654,
#  'threw': 4496,
#  'viewer': 4766,
#  'transformation': 4585,
#  'actress': 122,
#  'gone': 1960,
#  'body': 551,
#  'ms': 2933,
#  'hardly': 2065,
#  'kennedy': 2466,
#  'center': 752,
#  'mystery': 2959,
#  'front': 1864,
#  'mainly': 2714,
#  'deserved': 1241,
#  'feeling': 1710,
#  'cross': 1103,
#  'desperate': 1249,
#  'wife': 4896,
#  'known': 2499,
#  'feature': 1704,
#  'combined': 919,
#  'mild': 2843,
#  'dose': 1360,
#  'serf': 3928,
#  'setting': 3941,
#  'navy': 2980,
#  'kept': 2468,
#  'distance': 1331,
#  'away': 392,
#  'men': 2811,
#  'honor': 2166,
#  'based': 430,
#  'experience': 1611,
#  'service': 3937,
#  'black': 519,
#  'master': 2768,
#  'chief': 813,
#  'struggle': 4274,
#  'overcome': 3158,
#  'racism': 3525,
#  'eager': 1424,
#  'support': 4344,
#  'showing': 3999,
#  'side': 4006,
#  'helicopter': 2103,
#  'assault': 344,
#  'supporting': 4346,
#  'provided': 3472,
#  'tale': 4397,
#  'young': 4993,
#  'sailor': 3819,
#  'battle': 441,
#  'rage': 3528,
#  'shot': 3992,
#  'antwone': 279,
#  'fisher': 1761,
#  'wrote': 4975,
#  'denzel': 1221,
#  'washington': 4832,
#  'debut': 1183,
#  'psychiatrist': 3478,
#  'effectively': 1460,
#  'deeply': 1196,
#  'derek': 1233,
#  'luke': 2691,
#  'obviously': 3083,
#  'bright': 606,
#  'assigned': 345,
#  'seem': 3898,
#  'avoid': 387,
#  'minimal': 2859,
#  'fellow': 1713,
#  'sent': 3919,
#  'pre': 3384,
#  'proceeding': 3438,
#  'slowly': 4078,
#  'open': 3120,
#  'revealing': 3707,
#  'awful': 395,
#  'childhood': 815,
#  'brutality': 628,
#  'story': 4249,
#  'develops': 1266,
#  'increasingly': 2275,
#  'trust': 4620,
#  'doctor': 1342,
#  'courage': 1056,
#  'interest': 2334,
#  'named': 2966,
#  'joy': 2433,
#  'asking': 337,
#  'question': 3510,
#  'realizes': 3578,
#  'must': 2954,
#  'seek': 3896,
#  'answer': 273,
#  'painful': 3178,
#  'grow': 2012,
#  'move': 2925,
#  'conflict': 974,
#  'seeking': 3897,
#  'behavior': 467,
#  'while': 4881,
#  'race': 3522,
#  'foster': 1828,
#  'family': 1671,
#  'davis': 1165,
#  'number': 3069,
#  'recent': 3590,
#  'picture': 3286,
#  'nothing': 3055,
#  'compared': 942,
#  'mom': 2892,
#  'mrs': 2932,
#  'nelson': 2998,
#  'short': 3990,
#  'existed': 1600,
#  'oscar': 3141,
#  'gut': 2029,
#  'films': 1743,
#  'patient': 3227,
#  'interaction': 2333,
#  'follow': 1793,
#  'counter': 1050,
#  'stuff': 4281,
#  'gripping': 2006,
#  'period': 3253,
#  'sense': 3915,
#  'dealt': 1177,
#  'against': 164,
#  'person': 3255,
#  'truly': 4619,
#  'surviving': 4364,
#  'terrible': 4448,
#  'able': 79,
#  'victim': 4758,
#  'standing': 4197,
#  'tall': 4403,
#  'size': 4053,
#  'significance': 4012,
#  'brave': 590,
#  'strong': 4269,
#  'claim': 855,
#  'decent': 1186,
#  'life': 2600,
#  'aid': 178,
#  'caring': 714,
#  'my': 2956,
#  'listed': 2624,
#  'credit': 1088,
#  'officer': 3102,
#  'rank': 3543,
#  'criticism': 1100,
#  'playing': 3316,
#  'theater': 4466,
#  'deserves': 1242,
#  'wide': 4892,
#  'distribution': 1335,
#  'may': 2782,
#  'nomination': 3035,
#  '10': 2,
#  'masterpiece': 2770,
#  'footage': 1803,
#  'strange': 4254,
#  'begin': 464,
#  'day': 1169,
#  '35': 62,
#  'bar': 420,
#  'happen': 2055,
#  'minutes': 2865,
#  'amazingly': 232,
#  'complex': 955,
#  'using': 4722,
#  'element': 1472,
#  'realize': 3576,
#  'something': 4114,
#  'express': 1632,
#  'high': 2123,
#  'subtle': 4299,
#  'detail': 1258,
#  'incredibly': 2277,
#  'understandable': 4664,
#  'anyone': 282,
#  'cinema': 844,
#  'critic': 1098,
#  'but': 660,
#  'sound': 4126,
#  'european': 1560,
#  'white': 4883,
#  'low': 2679,
#  'scare': 3848,
#  'worth': 4956,
#  'expert': 1615,
#  'genre': 1917,
#  'is': 2372,
#  'tell': 4436,
#  'since': 4032,
#  'last': 2531,
#  'exactly': 1579,
#  'spoil': 4170,
#  'online': 3118,
#  'understand': 4663,
#  'spent': 4156,
#  'post': 3371,
#  'comment': 930,
#  'it': 2377,
#  'disappointed': 1308,
#  'trailer': 4579,
#  'appreciation': 302,
#  'professional': 3449,
#  've': 4743,
#  'done': 1353,
#  'save': 3841,
#  'india': 2280,
#  'beautifully': 453,
#  'color': 911,
#  'alright': 219,
#  'nevertheless': 3007,
#  'beauty': 454,
#  'place': 3301,
#  'head': 2083,
#  'tail': 4393,
#  'stunt': 4286,
#  'used': 4718,
#  'akshay': 186,
#  'kumar': 2505,
#  'worst': 4955,
#  '90': 74,
#  'guess': 2019,
#  'initial': 2300,
#  'car': 704,
#  'falling': 1667,
#  'flying': 1786,
#  'word': 4943,
#  'road': 3746,
#  'lake': 2520,
#  'and': 250,
#  'mentioned': 2817,
#  'nearly': 2984,
#  '30': 60,
#  'min': 2853,
#  'sure': 4350,
#  'audience': 373,
#  'forget': 1813,
#  'writer': 4970,
#  'drew': 1387,
#  'barrymore': 427,
#  'patrick': 3228,
#  'leslie': 2586,
#  'sally': 3823,
#  'fbi': 1701,
#  'agent': 169,
#  'holly': 2153,
#  'weird': 4860,
#  'hot': 2188,
#  'intimate': 2342,
#  'stranger': 4256,
#  'worked': 4946,
#  'worm': 4950,
#  'nathan': 2973,
#  'handsome': 2051,
#  'cat': 734,
#  'followed': 1794,
#  'mr': 2931,
#  'attacked': 361,
#  'dr': 1369,
#  'wallace': 4810,
#  'around': 317,
#  'male': 2724,
#  'stated': 4211,
#  'elizabeth': 1475,
#  'outside': 3153,
#  'victor': 4759,
#  'mistake': 2878,
#  'sullivan': 4326,
#  'easily': 1433,
#  'gorgeous': 1966,
#  'never': 3006,
#  'visually': 4784,
#  'stunning': 4285,
#  'aside': 334,
#  'woman': 4931,
#  'saga': 3817,
#  'involved': 2358,
#  'search': 3881,
#  'whose': 4889,
#  'defined': 1200,
#  'history': 2141,
#  'characterization': 781,
#  'flick': 1777,
#  'uncomfortable': 4656,
#  'depicted': 1223,
#  'african': 159,
#  'individual': 2284,
#  'heroic': 2115,
#  'sympathy': 4385,
#  'finale': 1745,
#  'lion': 2620,
#  'attack': 360,
#  'reaction': 3565,
#  'modern': 2889,
#  'gore': 1965,
#  'depiction': 1225,
#  'liked': 2608,
#  'positive': 3365,
#  'overdone': 3159,
#  'point': 3330,
#  'absurdity': 87,
#  'spoke': 4173,
#  'expect': 1605,
#  'old': 3109,
#  'nephew': 3001,
#  'speak': 4141,
#  'pretending': 3409,
#  'stone': 4242,
#  'hearted': 2091,
#  'cop': 1033,
#  'ultra': 4648,
#  'seemed': 3899,
#  'amateurish': 229,
#  'buy': 664,
#  'cheap': 797,
#  'opening': 3122,
#  'music': 2950,
#  'police': 3337,
#  'torture': 4554,
#  'actual': 123,
#  'event': 1565,
#  'cox': 1063,
#  'added': 130,
#  'apparently': 292,
#  'cool': 1031,
#  'disappointment': 1310,
#  'bound': 575,
#  'stopped': 4246,
#  'wasted': 4834,
#  'renting': 3660,
#  'least': 2566,
#  'writing': 4972,
#  'review': 3711,
#  'hopefully': 2173,
#  'saving': 3843,
#  'others': 3144,
#  'knew': 2491,
#  'prior': 3430,
#  'seeing': 3895,
#  'robot': 3754,
#  'another': 272,
#  'cheesy': 806,
#  'sci': 3858,
#  'fi': 1722,
#  '1950': 19,
#  'noted': 3054,
#  'studio': 4279,
#  'budget': 634,
#  'production': 3446,
#  'value': 4735,
#  'coming': 928,
#  'era': 1542,
#  'war': 4820,
#  'world': 4949,
#  'darker': 1156,
#  'forbidden': 1806,
#  'planet': 3307,
#  'fit': 1764,
#  'alien': 202,
#  'territory': 4452,
#  'what': 4872,
#  'impressed': 2257,
#  'immediately': 2247,
#  'rendition': 3656,
#  'cinematography': 847,
#  'scope': 3863,
#  'walter': 4812,
#  'home': 2158,
#  'cake': 673,
#  'underground': 4659,
#  'served': 3936,
#  'appeared': 297,
#  'technology': 4428,
#  'advanced': 145,
#  'consider': 987,
#  'released': 3631,
#  'sat': 3833,
#  'awe': 393,
#  'experienced': 1612,
#  'large': 2527,
#  'living': 2635,
#  'room': 3774,
#  'offered': 3099,
#  'fairly': 1659,
#  'stretch': 4262,
#  'imagine': 2242,
#  'direct': 1294,
#  'trek': 4600,
#  'series': 3931,
#  'gene': 1908,
#  'impact': 2250,
#  'vision': 4778,
#  'recognize': 3593,
#  'double': 1361,
#  'united': 4688,
#  'headed': 2084,
#  'presented': 3401,
#  'created': 1078,
#  'three': 4495,
#  'st': 4185,
#  'took': 4547,
#  'turn': 4628,
#  'defend': 1198,
#  'iv': 2382,
#  'certainly': 758,
#  'unique': 4686,
#  'concept': 965,
#  'dealing': 1176,
#  'martian': 2758,
#  'grotesque': 2009,
#  'space': 4134,
#  'creature': 1085,
#  'magic': 2708,
#  'helping': 2108,
#  'adam': 126,
#  'explained': 1617,
#  'looking': 2656,
#  'far': 1678,
#  'actually': 124,
#  'relative': 3627,
#  'come': 920,
#  'hall': 2039,
#  'went': 4865,
#  'bang': 417,
#  'photographer': 3277,
#  'career': 709,
#  'passing': 3219,
#  'proud': 3468,
#  'crime': 1094,
#  'of': 3094,
#  'ai': 177,
#  'tom': 4537,
#  'hank': 2054,
#  'paul': 3230,
#  'newman': 3011,
#  'amount': 242,
#  'none': 3037,
#  'hit': 2142,
#  'town': 4567,
#  'bos': 569,
#  'redeeming': 3602,
#  'quality': 3506,
#  'wanting': 4819,
#  'son': 4118,
#  'wind': 4908,
#  'killer': 2480,
#  'although': 223,
#  'teach': 4418,
#  'robbery': 3749,
#  'huh': 2200,
#  'cinematographer': 846,
#  'paint': 3180,
#  'work': 4945,
#  'awesome': 394,
#  'normally': 3043,
#  'half': 2037,
#  'hour': 2190,
#  'dialogue': 1272,
#  'teacher': 4419,
#  'sorry': 4123,
#  'girl': 1936,
#  'killing': 2481,
#  'stealing': 4220,
#  'van': 4737,
#  'drug': 1399,
#  'getting': 1928,
#  'heavy': 2096,
#  'shooting': 3987,
#  'innocent': 2305,
#  'her': 2112,
#  'generic': 1913,
#  'ran': 3537,
#  'instead': 2318,
#  'sum': 4327,
#  'personality': 3258,
#  'chicken': 812,
#  'usa': 4716,
#  'network': 3005,
#  'wonder': 4933,
#  'underrated': 4662,
#  'bollywood': 554,
#  'this': 4484,
#  'blockbuster': 535,
#  'direction': 1297,
#  'remember': 3646,
#  'running': 3799,
#  'somewhere': 4117,
#  'march': 2743,
#  'song': 4119,
#  'highest': 2125,
#  'volume': 4791,
#  'how': 2194,
#  'south': 4131,
#  'silver': 4018,
#  'with': 4922,
#  'indian': 2281,
#  'punk': 3491,
#  'rock': 3756,
#  'start': 4207,
#  'finish': 1753,
#  'ramones': 3536,
#  'late': 2533,
#  '70s': 70,
#  'school': 3857,
#  'roll': 3763,
#  'obsessed': 3080,
#  'band': 416,
#  'keep': 2461,
#  'join': 2423,
#  'meanwhile': 2793,
#  'hired': 2137,
#  'brand': 588,
#  'principal': 3427,
#  'amazon': 233,
#  'student': 4278,
#  'couple': 1055,
#  'act': 114,
#  'report': 3668,
#  'dirt': 1302,
#  'especially': 1548,
#  'determined': 1261,
#  'put': 3503,
#  'stop': 4245,
#  'clever': 869,
#  'kudos': 2504,
#  'superb': 4336,
#  'mary': 2763,
#  'legendary': 2576,
#  'clint': 879,
#  'howard': 2195,
#  'perform': 3246,
#  '70': 69,
#  'fan': 1673,
#  'terrific': 4450,
#  'blast': 527,
#  'literally': 2628,
#  'pathetic': 3225,
#  'for': 1805,
#  'believe': 474,
#  'spacey': 4135,
#  'freeman': 1852,
#  'morgan': 2910,
#  'constantly': 996,
#  'talking': 4402,
#  'saying': 3846,
#  'boy': 581,
#  'girlfriend': 1937,
#  'calling': 678,
#  'awkward': 398,
#  'hell': 2104,
#  'behind': 469,
#  'thinking': 4481,
#  'hole': 2150,
#  'horrid': 2181,
#  'confusing': 977,
#  'angle': 259,
#  'lame': 2521,
#  'background': 404,
#  'absolutely': 85,
#  'unbearable': 4652,
#  'rented': 3659,
#  'flop': 1781,
#  'expectation': 1606,
#  'sucked': 4308,
#  'hated': 2076,
#  'episode': 1536,
#  'hippy': 2135,
#  '1999': 42,
#  'came': 680,
#  'paramount': 3200,
#  'channel': 775,
#  'surprise': 4354,
#  'found': 1831,
#  'hilarious': 2128,
#  'judge': 2435,
#  'week': 4857,
#  'simon': 4023,
#  'ray': 3558,
#  'editor': 1453,
#  'oz': 3167,
#  'magazine': 2706,
#  'called': 677,
#  'mouth': 2924,
#  'feminist': 1716,
#  'laid': 2519,
#  'alex': 197,
#  'wit': 4920,
#  '60': 68,
#  'incredible': 2276,
#  'amongst': 241,
#  'change': 772,
#  'nobody': 3029,
#  ...}

# %% [markdown]
# # Model Training

# %%
#Cross Validation using KNN
from sklearn.model_selection import cross_val_score
from sklearn.neighbors import KNeighborsClassifier

#Test different K values
k_values = range(7, 35, 2)
scores = []
for i in range(0, len(k_values)):
    knn = KNeighborsClassifier(n_neighbors = k_values[i])
    scores.append(cross_val_score(knn, train_X, train_y , cv=5).mean())

print('Max Score: ', max(scores))
print('Max K: ', k_values[scores.index(max(scores))])
# Out:
# Max Score:  0.78808
# Max K:  33

# %%
#Plot K values
import matplotlib.pyplot as plt
plt.plot(k_values, scores)
plt.title('Accuracy vs K')
plt.xlabel('K')
plt.ylabel('Cross Val Acc')
plt.show()

# %% [markdown]
# Well, the curve seems to be going up (though the increase is not great). Might we worth testing greater K values.

# %%
#Fit best KNN
knn = KNeighborsClassifier(n_neighbors = k_values[scores.index(max(scores))])
knn.fit(train_X, train_y)
# Out:
# KNeighborsClassifier(n_neighbors=33)

# %% [markdown]
# # Testing

# %%
#Evaluate performance on test set
from sklearn.metrics import classification_report
print(classification_report(test_y, knn.predict(vectorizer.transform(test_X))))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.74      0.74      0.74     12500
#            1       0.74      0.74      0.74     12500
#
#     accuracy                           0.74     25000
#    macro avg       0.74      0.74      0.74     25000
# weighted avg       0.74      0.74      0.74     25000
